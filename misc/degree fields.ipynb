# %%
import sys
sys.path
# Out:
# ['',
#  '/usr/lib/python36.zip',
#  '/usr/lib/python3.6',
#  '/usr/lib/python3.6/lib-dynload',
#  '/home/jus/.local/lib/python3.6/site-packages',
#  '/usr/local/lib/python3.6/dist-packages',
#  '/usr/local/lib/python3.6/dist-packages/PySceneDetect-0.3.6-py3.6.egg',
#  '/usr/local/lib/python3.6/dist-packages/setuptools-40.4.3-py3.6.egg',
#  '/usr/lib/python3/dist-packages',
#  '/usr/lib/python3/dist-packages/IPython/extensions',
#  '/home/jus/.ipython']

# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 99)

# %%
df = pd.read_csv('y.csv', encoding='Latin-1')
# Out:
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (41,57,59,65,68) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.sample(9)
# Out:
#        AC_will_call__c AQ_Location_Campus__c  AQ_Program_Id__c  \
# 29303                0        Langley Campus              40.0
# 5271                 0        Langley Campus              57.0
# 79430                0                   NaN               NaN
# 72579                0                   NaN               NaN
# 48380                0       Richmond Campus             148.0
# 89951                0                   NaN               NaN
# 26049                0        Langley Campus              57.0
# 5062                 0        Langley Campus              48.0
# 51786                0                   NaN               NaN
#
#        Academic_History_Section_HS__c  Academic_History_Section_PS__c  \
# 29303                               0                               0
# 5271                                0                               0
# 79430                               0                               0
# ...

# %%
df.AQ_Program_Id__c.fillna(-1).astype(int)
# Out:
# 0        278
# 1        278
# 2        153
# 3        267
# 4         57
# 5        378
# 6        153
# 7        153
# 8        128
# 9         65
# 10        65
# 11        65
# 12       128
# 13       374
# 14       153
# 15        85
# 16        60
# 17        60
# 18        85
# 19         5
# 20       128
# 21       118
# 22        57
# 23       270
# 24        31
# 25       153
# 26        57
# 27        48
# 28        57
# 29        69
# 30        65
# 31       118
# 32        71
# 33        71
# 34        71
# 35        69
# 36        69
# 37        69
# 38        69
# 39        71
# 40       316
# 41       270
# 42        58
# 43        65
# 44       118
# 45        62
# 46       153
# 47       153
# 48       153
#         ...
# 90431     -1
# 90432     -1
# 90433     -1
# 90434     -1
# 90435     -1
# 90436     -1
# 90437     -1
# 90438     -1
# 90439     -1
# 90440     -1
# 90441     -1
# 90442     -1
# 90443     -1
# 90444     -1
# 90445     -1
# 90446     -1
# ...

# %% [markdown]
# # Degree related tables and columns
#
# |TABLE|COLUMN|NULLABLE?|DATATYPE|LEN/PREC|SCALE|
# |-----|------|---------|--------|--------|-----|
# |CERTIFICATION_DEF|BEGIN_DTE|YES|datetime|0||
# |CERTIFICATION_DEF|CERT_CDE|NO|char|5||
# |CERTIFICATION_DEF|CERT_DESC|YES|char|50||
# |CERTIFICATION_DEF|CERT_INTRNL|NO|char|1||
# |CERTIFICATION_DEF|CIP_CDE|YES|char|6||
# |CERTIFICATION_DEF|CIP_CDE_EXT|YES|char|6||
# |CERTIFICATION_DEF|DEGR_CDE|YES|char|5||
# |CERTIFICATION_DEF|END_DTE|YES|datetime|0||
# |CERTIFICATION_DEF|INSTITUT_DIV_CDE|YES|char|2||
# |CERTIFICATION_DEF|JOB_NAME|YES|char|30||
# |CERTIFICATION_DEF|JOB_TIME|YES|datetime|0||
# |CERTIFICATION_DEF|PERKINS_PROG|NO|char|1||
# |CERTIFICATION_DEF|PRIOR_PROG_NAME|YES|varchar|50||
# |CERTIFICATION_DEF|PROG_CATEGORY|YES|char|2||
# |CERTIFICATION_DEF|PROG_TYPE|YES|char|2||
# |CERTIFICATION_DEF|REQUIRES_ENGLISH|NO|char|1||
# |CERTIFICATION_DEF|TEACH_ELIGIBLE|NO|char|1||
# |CERTIFICATION_DEF|UDEF_1A_1|YES|char|1||
# |CERTIFICATION_DEF|UDEF_3A_1|YES|char|3||
# |CERTIFICATION_DEF|UDEF_DTE_1|YES|datetime|0||
# |CERTIFICATION_DEF|UDEF_DTE_2|YES|datetime|0||
# |CERTIFICATION_DEF|UDEF_DTE_3|YES|datetime|0||
# |CERTIFICATION_DEF|USER_NAME|YES|varchar|513||
# |DEGREE_AIM_XREF|ADV_REQ_CODE|NO|char|8||
# |DEGREE_AIM_XREF|ADV_TREE_YR_CDE|NO|char|4||
# |DEGREE_AIM_XREF|AIM_LABEL|NO|char|5||
# |DEGREE_AIM_XREF|ELEMENT_CDE|NO|char|5||
# |DEGREE_AIM_XREF|ELEMENT_TYPE|NO|char|3||
# |DEGREE_AIM_XREF|PRIMARY_AIM|NO|char|1||
# |DEGREE_DEFINITION|DEGREE|NO|char|5||
# |DEGREE_DEFINITION|DEGREE_DESC|YES|char|25||
# |DEGREE_DEFINITION|IPEDS_AWARD_LEVEL|YES|char|2||
# |DEGREE_DEFINITION|JOB_NAME|YES|varchar|30||
# |DEGREE_DEFINITION|JOB_TIME|YES|datetime|0||
# |DEGREE_DEFINITION|NSC_DEG_LEVEL|YES|char|1||
# |DEGREE_DEFINITION|PESC_ACAD_AWARD_LVL|YES|varchar|5||
# |DEGREE_DEFINITION|USER_NAME|YES|varchar|513||
# |DEGREE_HISTORY|ACAD_DEGR_CDE|YES|char|5||
# |DEGREE_HISTORY|ADV_TREE_YR_CDE|YES|char|4||
# |DEGREE_HISTORY|CERTIFICATION_1|YES|char|5||
# |DEGREE_HISTORY|CERTIFICATION_2|YES|char|5||
# |DEGREE_HISTORY|CERTIFICATION_3|YES|char|5||
# |DEGREE_HISTORY|CLASS_RANK|YES|char|5||
# |DEGREE_HISTORY|CLASS_RANK_HI_RNGE|YES|char|5||
# |DEGREE_HISTORY|CLASS_SIZE|YES|char|5||
# |DEGREE_HISTORY|CONCENTRATION_1|YES|char|5||
# |DEGREE_HISTORY|CONCENTRATION_2|YES|char|5||
# |DEGREE_HISTORY|CONCENTRATION_3|YES|char|5||
# |DEGREE_HISTORY|CONCENTRATION_4|YES|char|5||
# |DEGREE_HISTORY|CONCENTRATION_5|YES|char|5||
# |DEGREE_HISTORY|CUR_DEGREE|NO|char|1||
# |DEGREE_HISTORY|DEGR_CDE|YES|char|5||
# |DEGREE_HISTORY|DEGR_EARNED_AT|YES|char|6||
# |DEGREE_HISTORY|DEGR_HONORS_1|YES|char|5||
# |DEGREE_HISTORY|DEGR_HONORS_2|YES|char|5||
# |DEGREE_HISTORY|DEGR_HONORS_3|YES|char|5||
# |DEGREE_HISTORY|DIV_CDE|YES|char|2||
# |DEGREE_HISTORY|DTE_DEGR_CONFERRED|YES|datetime|0||
# |DEGREE_HISTORY|ENTRY_DTE|YES|datetime|0||
# |DEGREE_HISTORY|EXIT_DTE|YES|datetime|0||
# |DEGREE_HISTORY|EXIT_REASON|YES|char|2||
# |DEGREE_HISTORY|EXPECT_GRAD_TRM|YES|char|2||
# |DEGREE_HISTORY|EXPECT_GRAD_YR|YES|char|4||
# |DEGREE_HISTORY|ID_NUM|NO|int|10|0|
# |DEGREE_HISTORY|JOB_NAME|YES|varchar|30||
# |DEGREE_HISTORY|JOB_TIME|YES|datetime|0||
# |DEGREE_HISTORY|LAST_LEAVE_OF_ABSE|YES|datetime|0||
# |DEGREE_HISTORY|LAST_LEAVE_OF_ABSE_END_DTE|YES|datetime|0||
# |DEGREE_HISTORY|MAJOR_1|YES|char|5||
# |DEGREE_HISTORY|MAJOR_2|YES|char|5||
# |DEGREE_HISTORY|MAJOR_3|YES|char|5||
# |DEGREE_HISTORY|MINOR_1|YES|char|5||
# |DEGREE_HISTORY|MINOR_2|YES|char|5||
# |DEGREE_HISTORY|MINOR_3|YES|char|5||
# |DEGREE_HISTORY|NON_DEGREE_SEEKING|NO|char|1||
# |DEGREE_HISTORY|NUM_LEAVE_OF_ABSEN|NO|int|10|0|
# |DEGREE_HISTORY|PRT_DEGR_ON_TRANSC|NO|char|1||
# |DEGREE_HISTORY|REENTRY_DTE|YES|datetime|0||
# |DEGREE_HISTORY|SEQ_NUM_2|NO|int|10|0|
# |DEGREE_HISTORY|STUD_GEN_INTENT|YES|char|2||
# |DEGREE_HISTORY|UDEF_1A_1|YES|char|1||
# |DEGREE_HISTORY|UDEF_1A_2|YES|char|1||
# |DEGREE_HISTORY|UDEF_1A_3|YES|char|1||
# |DEGREE_HISTORY|UDEF_1A_4|YES|char|1||
# |DEGREE_HISTORY|UDEF_1A_5|YES|char|1||
# |DEGREE_HISTORY|UDEF_2A_1|YES|char|2||
# |DEGREE_HISTORY|UDEF_2A_2|YES|char|2||
# |DEGREE_HISTORY|UDEF_2A_3|YES|char|2||
# |DEGREE_HISTORY|UDEF_3A_1|YES|char|3||
# |DEGREE_HISTORY|UDEF_3A_2|YES|char|3||
# |DEGREE_HISTORY|UDEF_5_2_1|NO|numeric|5|2|
# |DEGREE_HISTORY|UDEF_5_2_3|NO|numeric|5|2|
# |DEGREE_HISTORY|UDEF_5_2_4|NO|numeric|5|2|
# |DEGREE_HISTORY|UDEF_5A_1|YES|char|5||
# |DEGREE_HISTORY|UDEF_5A_2|YES|char|5||
# |DEGREE_HISTORY|UDEF_DTE_1|YES|datetime|0||
# |DEGREE_HISTORY|UDEF_DTE_2|YES|datetime|0||
# |DEGREE_HISTORY|USDEF_5_2_2|NO|numeric|5|2|
# |DEGREE_HISTORY|USER_NAME|YES|varchar|513||
# |DEGREE_HISTORY|WITHDRAWAL_DTE|YES|datetime|0||
# |HONOR_DEFINITION|HONOR_CDE|NO|char|5||
# |HONOR_DEFINITION|HONOR_DESC|YES|char|25||
# |HONOR_DEFINITION|HONOR_TYPE|NO|char|1||
# |HONOR_DEFINITION|JOB_NAME|YES|varchar|30||
# |HONOR_DEFINITION|JOB_TIME|YES|datetime|0||
# |HONOR_DEFINITION|USER_NAME|YES|varchar|513||
# |MAJOR_MINOR_DEF|BEGIN_DTE|YES|datetime|0||
# |MAJOR_MINOR_DEF|CIP_CDE|YES|char|6||
# |MAJOR_MINOR_DEF|CIP_CDE_EXT|YES|char|6||
# |MAJOR_MINOR_DEF|DEGR_CDE|YES|char|5||
# |MAJOR_MINOR_DEF|END_DTE|YES|datetime|0||
# |MAJOR_MINOR_DEF|INSTITUT_DIV_CDE|YES|char|2||
# |MAJOR_MINOR_DEF|JOB_NAME|YES|varchar|30||
# |MAJOR_MINOR_DEF|JOB_TIME|YES|datetime|0||
# |MAJOR_MINOR_DEF|MAJOR_CDE|NO|char|5||
# |MAJOR_MINOR_DEF|MAJOR_MINOR_BOTH|NO|char|1||
# |MAJOR_MINOR_DEF|MAJOR_MINOR_DESC|YES|char|50||
# |MAJOR_MINOR_DEF|MAJOR_MINOR_INTRNL|NO|char|1||
# |MAJOR_MINOR_DEF|PERKINS_PROG|NO|char|1||
# |MAJOR_MINOR_DEF|PRIOR_PROG_NAME|YES|varchar|50||
# |MAJOR_MINOR_DEF|PROG_CATEGORY|YES|char|2||
# |MAJOR_MINOR_DEF|PROG_TYPE|YES|char|2||
# |MAJOR_MINOR_DEF|REQUIRES_ENGLISH|NO|char|1||
# |MAJOR_MINOR_DEF|TEACH_ELIGIBLE|NO|char|1||
# |MAJOR_MINOR_DEF|UDEF_1A_1|YES|char|1||
# |MAJOR_MINOR_DEF|UDEF_3A_1|YES|char|3||
# |MAJOR_MINOR_DEF|UDEF_DTE_1|YES|datetime|0||
# |MAJOR_MINOR_DEF|UDEF_DTE_2|YES|datetime|0||
# |MAJOR_MINOR_DEF|UDEF_DTE_3|YES|datetime|0||
# |MAJOR_MINOR_DEF|USER_NAME|YES|varchar|513||

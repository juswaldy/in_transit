# %%
import numpy as np
import pandas as pd
import PIL
from PIL import Image
from PIL import ImageFilter
from PIL import ImageStat
from PIL import ImageOps
from glob import glob
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')

# %%
files = glob("*.[Jj][Pp][Gg]")

# %%
plt.figure()
h = []
for f in sorted(files):
    x = Image.open(f)
    plt.plot(x.histogram())
    h.append(x.histogram())

plt.show()
np.shape(h)
# Out:
# (52, 768)

# %%
plt.plot(np.mean(h, 0))
plt.show()

# %%
x = Image.open(files[1])
x
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1382x1054 at 0x7FB9375FD860>

# %%
y = x.convert('L')
np.shape(y)
y = np.array(y)
np.shape(y)
y[y > 110] = 255
y[y < 255] = 0
z = Image.fromarray(y)
z = z.filter(ImageFilter.MinFilter((3)))
z
# Out:
# <PIL.Image.Image image mode=L size=1382x1054 at 0x7FB9375926A0>
